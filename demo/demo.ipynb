# %%
# line magic for debugging; delete in real sequence
# %load_ext autoreload
# %autoreload 2

# %%
from setup import *
# Out:
# Primary NI control card is PXI1Slot2
# All NI cards initialized
# All NI channels added

# %%
# clear these caches before programming a new sequence
exp.clear_edit_cache()
exp.clear_compile_cache()

# the channels (e.g. `MOT_AOM_1`) are defined in setup.py
# if you forget the physical channel, print the channel variable
# print(MOT_AOM_1)
exp.sine(*MOT_AOM_1,
         t=0,
         duration=1e-3,
         amplitude=1,
         freq=2e3,
         phase=0,
         dc_offset=0,
         keep_val = False)

exp.sine(*MOT_AOM_2,
         t=0,
         duration=1e-3,
         amplitude=1,
         freq=2e3,
         phase=0,
         dc_offset=0,
         keep_val = False)

exp.go_high(*coil_trigger, t=0.5e-3)
exp.go_low(*coil_trigger, t=0.75e-3)

run_sequence()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 29
#      26 exp.go_high(*coil_trigger, t=0.5e-3)
#      27 exp.go_low(*coil_trigger, t=0.75e-3)
# ---> 29 run_sequence()
#
# File z:\seqeunce-scripts\2024-11-11 DEMO\setup.py:100, in run_sequence(nreps, bufsize_ms)
#      98     exp.cfg_run(bufsize_ms=150)
#      99     for i in range(nreps):
# --> 100         exp.stream_run(calc_next=(i < nreps - 1))
#     101 finally:
#     102     exp.close_run()
#
# RuntimeError: [PXI1Slot7] DAQmx Error: Wait Until Done did not indicate that the task was done within the specified timeout.
# Increase the timeout, check the program, and make sure connections for external timing and triggering are in place.
#
# Task Name: _unnamedTask<3>
#
# Status Code: -200560

# %%
plot_sequence([MOT_AOM_1, MOT_AOM_2, coil_trigger])
